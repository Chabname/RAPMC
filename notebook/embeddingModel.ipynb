# %%
import sys
import os

# %%
sys.path.append(os.path.abspath("../src/"))

# %%
sys.path
# Out:
# ['/home/naha/Projets/github/RAPMC/notebook',
#  '/home/naha/.vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/pythonFiles',
#  '/home/naha/.vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/pythonFiles/lib/python',
#  '/home/naha/miniconda3/envs/RAPMC/lib/python38.zip',
#  '/home/naha/miniconda3/envs/RAPMC/lib/python3.8',
#  '/home/naha/miniconda3/envs/RAPMC/lib/python3.8/lib-dynload',
#  '',
#  '/home/naha/miniconda3/envs/RAPMC/lib/python3.8/site-packages',
#  '/home/naha/miniconda3/envs/RAPMC/lib/python3.8/site-packages/IPython/extensions',
#  '/home/naha/.ipython',
#  '/home/naha/Projets/github/RAPMC/src']

# %%
from Datas import Articles
from EmbW2V import EmbW2V

# %% [markdown]
# # CBOW Model

# %%
articles = Articles("../datas/all_data_clean.txt")

# %%
cbow_test = EmbW2V(articles.datas, 5, 10, 10000)
cbow_test.preprocess_datas(True)
# Out:
# _______________________________Preprocessing_____________________________
# ____________________________________________________________________
# Preprocessing finished in 45.46881988899986 seconds
# ____________________________________________________________________

# %%
cbow_test2 = EmbW2V([], 0, 0, 0)
cbow_test2.model_path = "../results/cbow_A3316_WS50_E500_B1000.model"
cbow_test2.plot_similarities(["mutation", "cell", "amplification", "egfr", "cancer", "heterozygous", "variant"] , 40)
# Out:
# this word does not exist into the model : amplification
# this word does not exist into the model : egfr
# this word does not exist into the model : cancer
# this word does not exist into the model : variant
